# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io

dataset = files.upload()
# Out:
#      <input type="file" id="files-d78b52bc-1138-4228-9aee-d9a9bfb06cff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d78b52bc-1138-4228-9aee-d9a9bfb06cff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('dataset.csv')
df.describe()
# Out:
#                No      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean   446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std    257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%    223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%    446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%    668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max    891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# The given dataset was a csv file, which is now converted into a dataframe. A summary of the dataframe is obtained by using describe(). The dataframe shows information regarding ticket booking. The average fare can be seen as 32 and the average age of the people who booked tickets can be observed as 29.

# %%
df
# Out:
#       No Survived  Pclass                                               Name  \
# 0      1       No       3                            Braund, Mr. Owen Harris
# 1      2      Yes       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3      Yes       3                             Heikkinen, Miss. Laina
# 3      4      Yes       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5       No       3                           Allen, Mr. William Henry
# ..   ...      ...     ...                                                ...
# 886  887       No       2                              Montvila, Rev. Juozas
# 887  888      Yes       1                       Graham, Miss. Margaret Edith
# 888  889       No       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890      Yes       1                              Behr, Mr. Karl Howell
# 890  891       No       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# *Data frame before changing Null values.*

# %%
df.Cabin.fillna('Unaivalable',inplace=True)
df.Age.fillna(float(29),inplace=True)#as age was not available, average age was given
df
# Out:
#       No Survived  Pclass                                               Name  \
# 0      1       No       3                            Braund, Mr. Owen Harris
# 1      2      Yes       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3      Yes       3                             Heikkinen, Miss. Laina
# 3      4      Yes       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5       No       3                           Allen, Mr. William Henry
# ..   ...      ...     ...                                                ...
# 886  887       No       2                              Montvila, Rev. Juozas
# 887  888      Yes       1                       Graham, Miss. Margaret Edith
# 888  889       No       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890      Yes       1                              Behr, Mr. Karl Howell
# 890  891       No       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# *Data frame after changing Null values.*

# %%
df.rename(columns={'No':'PassengerID'}, inplace=True)
df
# Out:
#      PassengerID Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# *Here, the column "No" was changed into "PassengerID".*

# %%
first = df.head(10).sort_values(by='Age')
first
# Out:
#    PassengerID Survived  Pclass  \
# 7            8       No       3
# 9           10      Yes       2
# 0            1       No       3
# 2            3      Yes       3
# 8            9      Yes       3
# 5            6       No       3
# 3            4      Yes       1
# 4            5       No       3
# 1            2      Yes       1
# 6            7       No       1
#
#                                                 Name     Sex   Age  SibSp  \
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 5                                   Moran, Mr. James    male  29.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# *Collecting sample data for simplicity of graph.*

# %%
first.plot(x='Age',y='Fare',kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# This Graph shows the plot between Age and Fare of passengers. From this graph, we can observe that people of age 38 have the most fare and the people of age group 22 to 29 is the least.
